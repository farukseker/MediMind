# %%
# Django starter

from pars_django_loader import DjangoLoader
DjangoLoader.auto()
# Out:
# Django has started...

# %%
from config.settings.base import BASE_DIR
print(BASE_DIR)
# Out:
# C:\Users\seker\Desktop\prod\uk_ile_savas\project\backend

# %%
import logging
logger = logging.getLogger('django.db.backends')
logger.setLevel(logging.DEBUG)
logger.addHandler(logging.StreamHandler())

# %%
from medication.models import (
    WeekDay,
    Medication,
    MedicationSchedule,
    MedicationLog,
    DailyNote,
    MedicationDoseTime,
)

# %%
Medication.objects.all()
# Out:
# <QuerySet [<Medication: test (None)>, <Medication: 10% Dekstroz Sudaki Cozeltisi 100 Ml (Medifleks-Setli) (None)>]>
